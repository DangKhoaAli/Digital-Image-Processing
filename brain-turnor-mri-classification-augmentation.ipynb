# %%
import torch
import torch.nn as nn
import wandb
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
import os
import numpy as np
import torch.nn.functional as F
import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: ", device)
# Out:
# Device:  cuda:0

# %%
wandb.login(key="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")
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# False

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
import numpy as np
from PIL import Image

class ClassificationDataset(Dataset):
    def __init__(self, root_dir, transform=None, augmentation=None):
        self.root_dir = root_dir
        # augmentation dành cho training, transform dành cho validation/test (chỉ resize + normalize)
        self.augmentation = augmentation
        self.transform = transform
        self.images = []
        self.labels = []
        self.class_to_idx = {
            'glioma': 0,
            'meningioma': 1,
            'pituitary': 2,
            'notumor': 3
        }
        for class_name in os.listdir(root_dir):
            class_dir = os.path.join(root_dir, class_name)
            if os.path.isdir(class_dir) and class_name in self.class_to_idx:
                for img_name in os.listdir(class_dir):
                    img_path = os.path.join(class_dir, img_name)
                    self.images.append(img_path)
                    self.labels.append(self.class_to_idx[class_name])

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        label = self.labels[idx]
        image = Image.open(img_path).convert('RGB')
        image = np.array(image)  # albumentations yêu cầu ảnh dạng numpy array

        if self.augmentation:
            augmented = self.augmentation(image=image)
            image = augmented['image']
        elif self.transform:
            # transform cũng là albumentations, gọi đúng cách
            transformed = self.transform(image=image)
            image = transformed['image']
        else:
            # fallback: chuyển về tensor và normalize
            transform = A.Compose([
                A.Resize(224, 224),
                A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
                ToTensorV2()
            ])
            image = transform(image=image)['image']

        return image, label, img_path

# %%
class ResidualInceptionBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualInceptionBlock, self).__init__()
        # Branch 1
        self.branch1 = nn.Conv2d(in_channels, out_channels // 4, kernel_size=1, stride=stride)

        # Branch 2
        self.branch2 = nn.Sequential(
            nn.Conv2d(in_channels, out_channels // 4, kernel_size=1, stride=stride),
            nn.BatchNorm2d(out_channels // 4),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels // 4, out_channels // 4, kernel_size=3, stride=1, padding=1)
        )

        # Branch 3
        self.branch3 = nn.Sequential(
            nn.Conv2d(in_channels, out_channels // 4, kernel_size=1, stride=stride),
            nn.BatchNorm2d(out_channels // 4),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels // 4, out_channels // 4, kernel_size=5, stride=1, padding=2)
        )

        # Branch 4 (Pooling)
        self.branch_pool = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=stride, padding=1),
            nn.Conv2d(in_channels, out_channels // 4, kernel_size=1, stride=1, padding=0)
        )

        # Batch Norm and Activation
        self.bn = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        # Shortcut Connection
        self.shortcut = nn.Sequential()
        if in_channels != out_channels or stride != 1:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch_pool(x)
        outputs = torch.cat([branch1, branch2, branch3, branch4], 1)
        outputs = self.bn(outputs)
        residual = self.shortcut(x)
        outputs += residual
        outputs = self.relu(outputs)
        return outputs
    
def make_layer(block, in_channels, out_channels, num_blocks, stride=1):
    layers = []
    layers.append(block(in_channels, out_channels, stride=stride))
    in_channels = out_channels  # Update in_channels for subsequent blocks
    for _ in range(1, num_blocks):
        layers.append(block(in_channels, out_channels, stride=1))
    return nn.Sequential(*layers)


class DeeperDetectionModel(nn.Module):
    def __init__(self, num_classes=2):
        super(DeeperDetectionModel, self).__init__()
        self.module1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )
        self.layer1 = make_layer(ResidualInceptionBlock, 64, 256, num_blocks=3, stride=1)
        self.layer2 = make_layer(ResidualInceptionBlock, 256, 512, num_blocks=4, stride=2)
        self.layer3 = make_layer(ResidualInceptionBlock, 512, 1024, num_blocks=6, stride=2)
        self.layer4 = make_layer(ResidualInceptionBlock, 1024, 2048, num_blocks=3, stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.module1(x)  # [B, 64, H/4, W/4]
        x = self.layer1(x)   # [B, 256, H/4, W/4]
        x = self.layer2(x)   # [B, 512, H/8, W/8]
        x = self.layer3(x)   # [B, 1024, H/16, W/16]
        x = self.layer4(x)   # [B, 2048, H/32, W/32]
        x = self.avgpool(x)  # [B, 2048, 1, 1]
        x = x.view(x.size(0), -1)  # [B, 2048]
        x = self.fc(x)  # [B, num_classes]
        return x

def create_detection_model(num_classes=2):
    model = DeeperDetectionModel(num_classes=num_classes)
    return model

# %%
train_augmentation = A.Compose([
    A.Resize(224, 224),
    A.Rotate(limit=15, p=0.5),                # xoay ngẫu nhiên trong khoảng ±15 độ
    A.HorizontalFlip(p=0.5),                   # lật ngang
    A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.5),
    A.GaussianBlur(blur_limit=(3, 5), p=0.3),  # làm mờ Gaussian
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# Transform cho validation/test: chỉ resize + normalize, không augmentation
val_transform = A.Compose([
    A.Resize(224, 224),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

train_dataset = ClassificationDataset(root_dir='/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training', augmentation=train_augmentation)
val_dataset = ClassificationDataset(root_dir='/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing', transform=val_transform)
# test_dataset = ClassificationDataset(root_dir='./Dataset_Arghadip/Test', transform=classification_transform)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
# test_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
classification_model = create_detection_model(num_classes = 4)
classification_model = classification_model.to(device)

# %%
from torchinfo import summary
summary_ = summary(classification_model, input_size = (16, 3, 256, 256))
summary_
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DeeperDetectionModel                     [16, 4]                   --
# ├─Sequential: 1-1                        [16, 64, 64, 64]          --
# │    └─Conv2d: 2-1                       [16, 64, 128, 128]        9,472
# │    └─BatchNorm2d: 2-2                  [16, 64, 128, 128]        128
# │    └─ReLU: 2-3                         [16, 64, 128, 128]        --
# │    └─MaxPool2d: 2-4                    [16, 64, 64, 64]          --
# ├─Sequential: 1-2                        [16, 256, 64, 64]         --
# │    └─ResidualInceptionBlock: 2-5       [16, 256, 64, 64]         --
# │    │    └─Conv2d: 3-1                  [16, 64, 64, 64]          4,160
# │    │    └─Sequential: 3-2              [16, 64, 64, 64]          41,216
# │    │    └─Sequential: 3-3              [16, 64, 64, 64]          106,752
# │    │    └─Sequential: 3-4              [16, 64, 64, 64]          4,160
# │    │    └─BatchNorm2d: 3-5             [16, 256, 64, 64]         512
# │    │    └─Sequential: 3-6              [16, 256, 64, 64]         17,152
# │    │    └─ReLU: 3-7                    [16, 256, 64, 64]         --
# │    └─ResidualInceptionBlock: 2-6       [16, 256, 64, 64]         --
# │    │    └─Conv2d: 3-8                  [16, 64, 64, 64]          16,448
# │    │    └─Sequential: 3-9              [16, 64, 64, 64]          53,504
# │    │    └─Sequential: 3-10             [16, 64, 64, 64]          119,040
# │    │    └─Sequential: 3-11             [16, 64, 64, 64]          16,448
# │    │    └─BatchNorm2d: 3-12            [16, 256, 64, 64]         512
# │    │    └─Sequential: 3-13             [16, 256, 64, 64]         --
# │    │    └─ReLU: 3-14                   [16, 256, 64, 64]         --
# │    └─ResidualInceptionBlock: 2-7       [16, 256, 64, 64]         --
# │    │    └─Conv2d: 3-15                 [16, 64, 64, 64]          16,448
# │    │    └─Sequential: 3-16             [16, 64, 64, 64]          53,504
# │    │    └─Sequential: 3-17             [16, 64, 64, 64]          119,040
# │    │    └─Sequential: 3-18             [16, 64, 64, 64]          16,448
# │    │    └─BatchNorm2d: 3-19            [16, 256, 64, 64]         512
# │    │    └─Sequential: 3-20             [16, 256, 64, 64]         --
# │    │    └─ReLU: 3-21                   [16, 256, 64, 64]         --
# ├─Sequential: 1-3                        [16, 512, 32, 32]         --
# │    └─ResidualInceptionBlock: 2-8       [16, 512, 32, 32]         --
# │    │    └─Conv2d: 3-22                 [16, 128, 32, 32]         32,896
# │    │    └─Sequential: 3-23             [16, 128, 32, 32]         180,736
# │    │    └─Sequential: 3-24             [16, 128, 32, 32]         442,880
# │    │    └─Sequential: 3-25             [16, 128, 32, 32]         32,896
# │    │    └─BatchNorm2d: 3-26            [16, 512, 32, 32]         1,024
# │    │    └─Sequential: 3-27             [16, 512, 32, 32]         132,608
# │    │    └─ReLU: 3-28                   [16, 512, 32, 32]         --
# │    └─ResidualInceptionBlock: 2-9       [16, 512, 32, 32]         --
# │    │    └─Conv2d: 3-29                 [16, 128, 32, 32]         65,664
# │    │    └─Sequential: 3-30             [16, 128, 32, 32]         213,504
# │    │    └─Sequential: 3-31             [16, 128, 32, 32]         475,648
# │    │    └─Sequential: 3-32             [16, 128, 32, 32]         65,664
# │    │    └─BatchNorm2d: 3-33            [16, 512, 32, 32]         1,024
# │    │    └─Sequential: 3-34             [16, 512, 32, 32]         --
# │    │    └─ReLU: 3-35                   [16, 512, 32, 32]         --
# │    └─ResidualInceptionBlock: 2-10      [16, 512, 32, 32]         --
# │    │    └─Conv2d: 3-36                 [16, 128, 32, 32]         65,664
# │    │    └─Sequential: 3-37             [16, 128, 32, 32]         213,504
# │    │    └─Sequential: 3-38             [16, 128, 32, 32]         475,648
# │    │    └─Sequential: 3-39             [16, 128, 32, 32]         65,664
# │    │    └─BatchNorm2d: 3-40            [16, 512, 32, 32]         1,024
# │    │    └─Sequential: 3-41             [16, 512, 32, 32]         --
# │    │    └─ReLU: 3-42                   [16, 512, 32, 32]         --
# │    └─ResidualInceptionBlock: 2-11      [16, 512, 32, 32]         --
# │    │    └─Conv2d: 3-43                 [16, 128, 32, 32]         65,664
# │    │    └─Sequential: 3-44             [16, 128, 32, 32]         213,504
# │    │    └─Sequential: 3-45             [16, 128, 32, 32]         475,648
# │    │    └─Sequential: 3-46             [16, 128, 32, 32]         65,664
# │    │    └─BatchNorm2d: 3-47            [16, 512, 32, 32]         1,024
# │    │    └─Sequential: 3-48             [16, 512, 32, 32]         --
# │    │    └─ReLU: 3-49                   [16, 512, 32, 32]         --
# ├─Sequential: 1-4                        [16, 1024, 16, 16]        --
# │    └─ResidualInceptionBlock: 2-12      [16, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-50                 [16, 256, 16, 16]         131,328
# │    │    └─Sequential: 3-51             [16, 256, 16, 16]         721,920
# │    │    └─Sequential: 3-52             [16, 256, 16, 16]         1,770,496
# │    │    └─Sequential: 3-53             [16, 256, 16, 16]         131,328
# │    │    └─BatchNorm2d: 3-54            [16, 1024, 16, 16]        2,048
# │    │    └─Sequential: 3-55             [16, 1024, 16, 16]        527,360
# │    │    └─ReLU: 3-56                   [16, 1024, 16, 16]        --
# │    └─ResidualInceptionBlock: 2-13      [16, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-57                 [16, 256, 16, 16]         262,400
# │    │    └─Sequential: 3-58             [16, 256, 16, 16]         852,992
# │    │    └─Sequential: 3-59             [16, 256, 16, 16]         1,901,568
# │    │    └─Sequential: 3-60             [16, 256, 16, 16]         262,400
# │    │    └─BatchNorm2d: 3-61            [16, 1024, 16, 16]        2,048
# │    │    └─Sequential: 3-62             [16, 1024, 16, 16]        --
# │    │    └─ReLU: 3-63                   [16, 1024, 16, 16]        --
# │    └─ResidualInceptionBlock: 2-14      [16, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-64                 [16, 256, 16, 16]         262,400
# │    │    └─Sequential: 3-65             [16, 256, 16, 16]         852,992
# │    │    └─Sequential: 3-66             [16, 256, 16, 16]         1,901,568
# │    │    └─Sequential: 3-67             [16, 256, 16, 16]         262,400
# │    │    └─BatchNorm2d: 3-68            [16, 1024, 16, 16]        2,048
# │    │    └─Sequential: 3-69             [16, 1024, 16, 16]        --
# │    │    └─ReLU: 3-70                   [16, 1024, 16, 16]        --
# │    └─ResidualInceptionBlock: 2-15      [16, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-71                 [16, 256, 16, 16]         262,400
# │    │    └─Sequential: 3-72             [16, 256, 16, 16]         852,992
# │    │    └─Sequential: 3-73             [16, 256, 16, 16]         1,901,568
# │    │    └─Sequential: 3-74             [16, 256, 16, 16]         262,400
# │    │    └─BatchNorm2d: 3-75            [16, 1024, 16, 16]        2,048
# │    │    └─Sequential: 3-76             [16, 1024, 16, 16]        --
# │    │    └─ReLU: 3-77                   [16, 1024, 16, 16]        --
# │    └─ResidualInceptionBlock: 2-16      [16, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-78                 [16, 256, 16, 16]         262,400
# │    │    └─Sequential: 3-79             [16, 256, 16, 16]         852,992
# │    │    └─Sequential: 3-80             [16, 256, 16, 16]         1,901,568
# │    │    └─Sequential: 3-81             [16, 256, 16, 16]         262,400
# │    │    └─BatchNorm2d: 3-82            [16, 1024, 16, 16]        2,048
# │    │    └─Sequential: 3-83             [16, 1024, 16, 16]        --
# │    │    └─ReLU: 3-84                   [16, 1024, 16, 16]        --
# │    └─ResidualInceptionBlock: 2-17      [16, 1024, 16, 16]        --
# │    │    └─Conv2d: 3-85                 [16, 256, 16, 16]         262,400
# │    │    └─Sequential: 3-86             [16, 256, 16, 16]         852,992
# │    │    └─Sequential: 3-87             [16, 256, 16, 16]         1,901,568
# │    │    └─Sequential: 3-88             [16, 256, 16, 16]         262,400
# │    │    └─BatchNorm2d: 3-89            [16, 1024, 16, 16]        2,048
# │    │    └─Sequential: 3-90             [16, 1024, 16, 16]        --
# │    │    └─ReLU: 3-91                   [16, 1024, 16, 16]        --
# ├─Sequential: 1-5                        [16, 2048, 8, 8]          --
# │    └─ResidualInceptionBlock: 2-18      [16, 2048, 8, 8]          --
# │    │    └─Conv2d: 3-92                 [16, 512, 8, 8]           524,800
# │    │    └─Sequential: 3-93             [16, 512, 8, 8]           2,885,632
# │    │    └─Sequential: 3-94             [16, 512, 8, 8]           7,079,936
# │    │    └─Sequential: 3-95             [16, 512, 8, 8]           524,800
# │    │    └─BatchNorm2d: 3-96            [16, 2048, 8, 8]          4,096
# │    │    └─Sequential: 3-97             [16, 2048, 8, 8]          2,103,296
# │    │    └─ReLU: 3-98                   [16, 2048, 8, 8]          --
# │    └─ResidualInceptionBlock: 2-19      [16, 2048, 8, 8]          --
# │    │    └─Conv2d: 3-99                 [16, 512, 8, 8]           1,049,088
# │    │    └─Sequential: 3-100            [16, 512, 8, 8]           3,409,920
# │    │    └─Sequential: 3-101            [16, 512, 8, 8]           7,604,224
# │    │    └─Sequential: 3-102            [16, 512, 8, 8]           1,049,088
# │    │    └─BatchNorm2d: 3-103           [16, 2048, 8, 8]          4,096
# │    │    └─Sequential: 3-104            [16, 2048, 8, 8]          --
# │    │    └─ReLU: 3-105                  [16, 2048, 8, 8]          --
# │    └─ResidualInceptionBlock: 2-20      [16, 2048, 8, 8]          --
# │    │    └─Conv2d: 3-106                [16, 512, 8, 8]           1,049,088
# │    │    └─Sequential: 3-107            [16, 512, 8, 8]           3,409,920
# │    │    └─Sequential: 3-108            [16, 512, 8, 8]           7,604,224
# │    │    └─Sequential: 3-109            [16, 512, 8, 8]           1,049,088
# │    │    └─BatchNorm2d: 3-110           [16, 2048, 8, 8]          4,096
# │    │    └─Sequential: 3-111            [16, 2048, 8, 8]          --
# │    │    └─ReLU: 3-112                  [16, 2048, 8, 8]          --
# ├─AdaptiveAvgPool2d: 1-6                 [16, 2048, 1, 1]          --
# ├─Linear: 1-7                            [16, 4]                   8,196
# ==========================================================================================
# Total params: 62,938,116
# Trainable params: 62,938,116
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 215.29
# ==========================================================================================
# Input size (MB): 12.58
# Forward/backward pass size (MB): 3539.99
# Params size (MB): 251.75
# Estimated Total Size (MB): 3804.33
# ==========================================================================================

# %%
criterion_classification = nn.CrossEntropyLoss()
optimizer_classification = optim.Adam(classification_model.parameters(), lr=1e-4)

# %%
from tqdm.notebook import tqdm
from datetime import datetime

# ⭐ FIX 1 — đóng run cũ nếu tồn tại
if wandb.run is not None:
    wandb.finish()
    
num_epochs = 50
total_len = len(train_loader) + len(val_loader)

train_losses = np.zeros(num_epochs)
test_losses = np.zeros(num_epochs)
train_acc = np.zeros(num_epochs)
test_acc = np.zeros(num_epochs)

best_test_acc = 0

run_time = datetime.now().strftime("%Y%m%d_%H%M%S")
run_name = f"resnet50_lr{optimizer_classification.param_groups[0]['lr']}_bs{train_loader.batch_size}_{run_time}"

wandb.init(
    project="medical_classification",
    name=run_name,
    config={
        "epochs": num_epochs,
        "lr": optimizer_classification.param_groups[0]["lr"],
        "batch_size": train_loader.batch_size
    }, reinit = True
)

wandb.watch(classification_model, log="gradients", log_freq = 200)

for epoch in range(num_epochs):
    epoch_str = str(epoch + 1).rjust(len(str(num_epochs)), " ")
    with tqdm(total = total_len, desc = f"Epoch [ {epoch_str}/{num_epochs} ] : ") as pbar:
        
        classification_model.train()
        n_correct = 0
        n_total = 0
        train_loss = []
        
        for inputs, targets,_ in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            optimizer_classification.zero_grad()
            
            outputs = classification_model(inputs)
            loss = criterion_classification(outputs, targets)
            train_loss.append(loss.item())
            
            loss.backward()
            optimizer_classification.step()
            
            _, prediction = torch.max(outputs, 1)
            
            n_correct += (prediction == targets).sum().item()
            n_total += targets.shape[0]
            
            pbar.update(1)
        
        # before_lr = optimizer.param_groups[0]["lr"]
        
        # after_lr = optimizer.param_groups[0]["lr"]
        
        train_loss = np.mean(train_loss)
        train_acc_real = n_correct/n_total
        train_losses[epoch] = train_loss
        train_acc[epoch] = train_acc_real
                
        classification_model.eval()
        n_correct = 0
        n_total = 0
        test_loss = []
        
        with torch.no_grad():
            for inputs, targets, _ in val_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                
                outputs = classification_model(inputs)
                
                loss = criterion_classification(outputs, targets)
                test_loss.append(loss.item())
                
                _, prediction = torch.max(outputs, 1)
                
                n_correct += (prediction == targets).sum().item()
                n_total += targets.shape[0]
                
                pbar.update(1)
            
        test_loss = np.mean(test_loss)
        test_acc_real = n_correct/n_total
        test_losses[epoch] = test_loss
        test_acc[epoch] = test_acc_real

        # scheduler.step()

        wandb.log({
            "train_loss": train_loss,
            "train_acc": train_acc_real,
            "test_loss": test_loss,
            "test_acc": test_acc_real,
            "lr": optimizer_classification.param_groups[0]["lr"]
        }, step=epoch)

        if test_acc_real > best_test_acc:
            best_test_acc = test_acc_real
            torch.save(classification_model.state_dict(), "best_model.pth")
            wandb.save("best_model.pth")
        
        pbar.set_description(f"Epoch [ {epoch_str}/{num_epochs} ] ")
        pbar.set_postfix({'Train acc' : f'{train_acc_real:.3f}',
                          'Train loss' : f'{train_loss:.3f}',
                          'Test acc' : f'{test_acc_real:.3f}',
                          'Test loss': f'{test_loss:.3f}'
                        #   'lr_before' : f'{before_lr}',
                        #   'lr_after' : f'{after_lr}'+
                         })
wandb.finish()
# Out:
#  View run <strong style="color:#cdcd00">resnet50_lr0.0001_bs16_20260318_073035</strong> at: <a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification/runs/qu2reizf' target="_blank">https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification/runs/qu2reizf</a><br> View project at: <a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification' target="_blank">https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260318_073035-qu2reizf/logs</code>
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20260318_073725-uuerx37p</code>
# Syncing run <strong><a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification/runs/uuerx37p' target="_blank">resnet50_lr0.0001_bs16_20260318_073725</a></strong> to <a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification' target="_blank">https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification</a>
#  View run at <a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification/runs/uuerx37p' target="_blank">https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification/runs/uuerx37p</a>
# Epoch [  1/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Epoch [  2/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [  3/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [  4/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [  5/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [  6/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [  7/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [  8/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [  9/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 10/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 11/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 12/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 13/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 14/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 15/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 16/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 17/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 18/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 19/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 20/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 21/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 22/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 23/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 24/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 25/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 26/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 27/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 28/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 29/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 30/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 31/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 32/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 33/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 34/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 35/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 36/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 37/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 38/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 39/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 40/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 41/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 42/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 43/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 44/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 45/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 46/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 47/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 48/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 49/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# Epoch [ 50/50 ] :   0%|          | 0/450 [00:00<?, ?it/s]
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_acc</td><td>▂▁▆▅▄▇▇▇▇▅█▇▇▇▇▇█▇████▇███████▇▇▇█▇████▇</td></tr><tr><td>test_loss</td><td>▅▆▃▅▆▂▄▅▄█▃▂▄▄▃▂▅▄▆▂▄▁▄▆▄▃▅▃▃▃▆▇▄▄▇▄▃▆▆▆</td></tr><tr><td>train_acc</td><td>▁▄▆▇▇▇▇▇█▇███▇██████████████████████████</td></tr><tr><td>train_loss</td><td>█▅▃▃▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>lr</td><td>0.0001</td></tr><tr><td>test_acc</td><td>0.93875</td></tr><tr><td>test_loss</td><td>0.82657</td></tr><tr><td>train_acc</td><td>0.99232</td></tr><tr><td>train_loss</td><td>0.02152</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">resnet50_lr0.0001_bs16_20260318_073725</strong> at: <a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification/runs/uuerx37p' target="_blank">https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification/runs/uuerx37p</a><br> View project at: <a href='https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification' target="_blank">https://wandb.ai/khoanguyen12062005-saigon-university/medical_classification</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20260318_073725-uuerx37p/logs</code>

# %%
classification_model.eval()
val_running_corrects = 0

n_correct = 0
n_total = 0

with torch.no_grad():
    for inputs, targets, __ in val_loader:
        inputs, targets = inputs.to(device), targets.to(device)
                
        outputs = classification_model(inputs)

        _, prediction = torch.max(outputs, 1)
                
        n_correct += (prediction == targets).sum().item()
        n_total += targets.shape[0]

test_acc_real = n_correct/n_total
print('Validation Accuracy: {:.4f}'.format(test_acc_real))
# Out:
# Validation Accuracy: 0.9387

# %%
import torch
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, r2_score
import numpy as np

# Assuming you have your model, data loaders, and device set up
classification_model.eval()
all_preds = []
all_labels = []
all_probs = []

with torch.no_grad():
    for inputs, labels, _ in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = classification_model(inputs)
        probs = torch.softmax(outputs, dim=1)
        _, preds = torch.max(outputs, 1)
        all_probs.extend(probs.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Convert lists to numpy arrays
all_preds = np.array(all_preds)
all_labels = np.array(all_labels)
all_probs = np.array(all_probs)

# Calculate metrics
precision = precision_score(all_labels, all_preds, average='weighted')
recall = recall_score(all_labels, all_preds, average='weighted')
f1 = f1_score(all_labels, all_preds, average='weighted')
auc = roc_auc_score(all_labels, all_probs, average='weighted', multi_class='ovr')
r2 = r2_score(all_labels, all_preds)

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
print(f'AUC: {auc}')
print(f'R2 Score: {r2}')
# Out:
# Precision: 0.9424126250521797
# Recall: 0.93875
# F1 Score: 0.9371768977490481
# AUC: 0.9754026041666667
# R2 Score: 0.779

# %%
print(wandb.run)
# Out:
# None

# %%
# Save the model
torch.save(classification_model.state_dict(), '/kaggle/working/model_Full.pth')

# # Later, to load the model, you would use:
# classification_model.load_state_dict(torch.load('/kaggle/working/model.pth'))
# classification_model.eval()  # Make sure to call eval mode when evaluating

# %%
import torch
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import cv2
from torchvision import transforms
from PIL import Image

class GradCAM:
    def __init__(self, model, target_layer):
        self.model = model
        self.target_layer = target_layer
        self.gradients = None
        self.activations = None
        self.hook_layers()

    def hook_layers(self):
        def forward_hook(module, input, output):
            self.activations = output
        def backward_hook(module, grad_in, grad_out):
            self.gradients = grad_out[0]
        self.target_layer.register_forward_hook(forward_hook)
        self.target_layer.register_backward_hook(backward_hook)

    def generate(self, input_image, target_class):
        self.model.eval()
        output = self.model(input_image)
        self.model.zero_grad()
        class_loss = F.cross_entropy(output, target_class)
        class_loss.backward()
        pooled_gradients = torch.mean(self.gradients, dim=[0, 2, 3])
        for i in range(self.activations.shape[1]):
            self.activations[:, i, :, :] *= pooled_gradients[i]
        heatmap = torch.mean(self.activations, dim=1).squeeze()
        heatmap = F.relu(heatmap)
        heatmap /= torch.max(heatmap)
        return heatmap.detach().cpu().numpy()

def show_cam_on_image(img, mask, title):
    mask = cv2.resize(mask, (img.shape[1], img.shape[0]))
    heatmap = cv2.applyColorMap(np.uint8(255 * mask), cv2.COLORMAP_JET)
    heatmap = np.float32(heatmap) / 255
    cam = heatmap + np.float32(img)
    cam = cam / np.max(cam)
    plt.imshow(cam)
    plt.axis('off')
    plt.title(title)

def load_model(model_path):
    model = create_detection_model(num_classes=4)
    model.load_state_dict(torch.load(model_path, weights_only=True))
    model = model.to(device)
    model.eval()
    return model

# Hyperparameters
model_path = '/kaggle/working/model_Full.pth'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the trained model
classification_model = load_model(model_path)

# Image paths
image_paths = {
    'glioma': '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma',
    'meningioma': '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/meningioma',
    'pituitary': '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/pituitary',
    'no_tumor': '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/notumor'
}

# Preprocess images
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

input_images = {}

for k, folder in image_paths.items():
    img_name = os.listdir(folder)[0]        # lấy ảnh đầu tiên
    img_path = os.path.join(folder, img_name)

    img = Image.open(img_path).convert("RGB")
    input_images[k] = preprocess(img).unsqueeze(0)

target_classes = {
    'glioma': torch.tensor([0]).to(device),
    'meningioma': torch.tensor([1]).to(device),
    'pituitary': torch.tensor([2]).to(device),
    'no_tumor': torch.tensor([3]).to(device)
}

# Specify target layers for Grad-CAM
target_layers = [
    classification_model.module1[3],    # MaxPool in module1
    classification_model.layer1[-1].bn, # BatchNorm in the last block of layer1
    classification_model.layer2[-1].bn, # BatchNorm in the last block of layer2
    classification_model.layer3[-1].bn, # BatchNorm in the last block of layer3
    classification_model.layer4[-1].bn  # BatchNorm in the last block of layer4
]

# Module names
module_names = ['NCAB', 'Initial TriSAE', 'QuadSAE', 'HexaSAE', 'Final SAE Fusion']
# Tumor types
tumor_types = ['glioma', 'meningioma', 'pituitary', 'no_tumor']

# Generate and display Grad-CAM heatmaps
fig, axes = plt.subplots(len(tumor_types), len(module_names), figsize=(15, 12))

for row, image_type in enumerate(tumor_types):
    input_image = input_images[image_type].to(device)
    target_class = target_classes[image_type]
    input_image_np = input_image.cpu().numpy().squeeze().transpose(1, 2, 0)
    
    for col, target_layer in enumerate(target_layers):
        grad_cam = GradCAM(model=classification_model, target_layer=target_layer)
        heatmap = grad_cam.generate(input_image, target_class)
        mask = cv2.resize(heatmap, (input_image_np.shape[1], input_image_np.shape[0]))
        heatmap_colormap = cv2.applyColorMap(np.uint8(255 * mask), cv2.COLORMAP_JET)
        cam = np.float32(heatmap_colormap) / 255 + np.float32(input_image_np)
        cam = cam / np.max(cam)
        
        axes[row, col].imshow(cam)
        axes[row, col].axis('off')
        if row == 0:
            axes[row, col].set_title(module_names[col], fontsize=12)
    axes[row, 0].set_ylabel(image_type, fontsize=12)

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.61523396..1.0].
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1866: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.59638536..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6003962..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6154469..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.60541314..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7699036..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6768553..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.61707664..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5818417..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.62733185..1.0].
# /tmp/ipykernel_55/144643874.py:120: RuntimeWarning: invalid value encountered in cast
#   heatmap_colormap = cv2.applyColorMap(np.uint8(255 * mask), cv2.COLORMAP_JET)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.8218888..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.68024445..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.63826..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6301161..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7202132..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5818417..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5818417..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5674128..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5846411..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.5724325..1.0].

# %%
import torch
import os
import shutil
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader

# ======================
# CONFIG
# ======================
model_path = "/kaggle/working/best_model.pth"
test_dir = "/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing"
save_wrong_dir = "/kaggle/working/wrong_predictions"
batch_size = 32

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ======================
# PREPROCESS
# ======================
transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485,0.456,0.406],
        std=[0.229,0.224,0.225]
    )
])

# ======================
# DATASET
# ======================
test_dataset = ImageFolder(root=test_dir, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

class_names = test_dataset.classes

# ======================
# LOAD MODEL
# ======================
model = create_detection_model(num_classes=4)
model.load_state_dict(torch.load(model_path))
model = model.to(device)
model.eval()

# ======================
# CREATE SAVE FOLDER
# ======================
os.makedirs(save_wrong_dir, exist_ok=True)

# ======================
# RUN TEST
# ======================
idx_global = 0

with torch.no_grad():
    for images, labels in test_loader:
        
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        preds = torch.argmax(outputs, dim=1)

        for i in range(images.size(0)):
            
            true_label = labels[i].item()
            pred_label = preds[i].item()

            if true_label != pred_label:

                true_name = class_names[true_label]
                pred_name = class_names[pred_label]

                folder_name = f"{true_name}_pred_{pred_name}"
                save_path = os.path.join(save_wrong_dir, folder_name)
                os.makedirs(save_path, exist_ok=True)

                # lấy đường dẫn ảnh gốc
                img_path, _ = test_dataset.samples[idx_global]

                shutil.copy(img_path, save_path)

            idx_global += 1

print("Done saving wrong predictions.")
# Out:
# Done saving wrong predictions.

# %%
import shutil

model = create_detection_model(num_classes=4)
model.load_state_dict(torch.load("/kaggle/working/best_model.pth"))
model.to(device)
model.eval()

wrong_dir = "wrong_predictions"
os.makedirs(wrong_dir, exist_ok=True)

test_loss = []
n_correct = 0
n_total = 0
global_idx = 0

class_names = ['glioma', 'meningioma', 'pituitary', 'notumor']

all_preds = []
all_targets = []

with torch.no_grad():
    for inputs, targets, paths in val_loader:

        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)

        loss = criterion_classification(outputs, targets)
        test_loss.append(loss.item())

        _, prediction = torch.max(outputs, 1)

        all_preds.extend(prediction.cpu().numpy())
        all_targets.extend(targets.cpu().numpy())

        for i in range(inputs.size(0)):

            true_label = targets[i].item()
            pred_label = prediction[i].item()

            if true_label != pred_label:
            
                true_name = class_names[true_label]
                pred_name = class_names[pred_label]
            
                save_folder = os.path.join(
                    wrong_dir,
                    f"{true_name}_pred_{pred_name}"
                )
            
                os.makedirs(save_folder, exist_ok=True)
            
                shutil.copy(paths[i], save_folder)

            global_idx += 1

        n_correct += (prediction == targets).sum().item()
        n_total += targets.shape[0]

accuracy = n_correct / n_total
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.9525

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

cm = confusion_matrix(all_targets, all_preds)

print("Confusion Matrix:")
print(cm)

plt.figure(figsize=(8,6))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Reds",
    xticklabels=class_names,
    yticklabels=class_names
)

plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix Heatmap")
plt.show()
# Out:
# Confusion Matrix:
# [[327  36   2  35]
#  [  0 398   2   0]
#  [  0   1 399   0]
#  [  0   0   0 400]]

# %%
import os
import math
from PIL import Image
import matplotlib.pyplot as plt

wrong_root = "wrong_predictions"
cols = 6
max_img = 24   # giới hạn số ảnh mỗi folder

for folder in sorted(os.listdir(wrong_root)):

    folder_path = os.path.join(wrong_root, folder)
    if not os.path.isdir(folder_path):
        continue

    images = os.listdir(folder_path)[:max_img]
    n = len(images)

    if n == 0:
        continue

    rows = math.ceil(n / cols)

    fig, axes = plt.subplots(rows, cols, figsize=(2.5*cols, 2.5*rows))
    fig.patch.set_facecolor("white")

    fig.suptitle(
        f"Misclassified: {folder}",
        fontsize=20,
        fontweight="bold",
        y=1.02
    )

    axes = axes.flatten()

    for i in range(rows * cols):

        ax = axes[i]

        if i < n:
            img_path = os.path.join(folder_path, images[i])
            img = Image.open(img_path).convert("RGB")

            ax.imshow(img)
            ax.set_xticks([])
            ax.set_yticks([])

            # ⭐ viền ảnh nhẹ
            for spine in ax.spines.values():
                spine.set_visible(True)
                spine.set_linewidth(0.5)
                spine.set_edgecolor("black")

        else:
            ax.axis("off")

    plt.subplots_adjust(
        left=0.02,
        right=0.98,
        top=0.90,
        bottom=0.02,
        wspace=0.05,
        hspace=0.15
    )

    plt.show()

# %%
# !zip -r wrong_predictions.zip wrong_predictions
# Out:
# updating: wrong_predictions/ (stored 0%)
# updating: wrong_predictions/notumor_pred_pituitary/ (stored 0%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_140.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_291.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_276.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_68.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_158.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_357.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_257.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_88.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_252.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_275.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_43.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_29.jpg (deflated 13%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_12.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_146.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_204.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_79.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_197.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_259.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_142.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_280.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_299.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_64.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_233.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_218.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_277.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_47.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_76.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_97.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_367.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_18.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_73.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_150.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_155.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_32.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_286.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_205.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_254.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_278.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_196.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_363.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_200.jpg (deflated 9%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_360.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_162.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_104.jpg (deflated 10%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_11.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_41.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_274.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_20.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_247.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_302.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_356.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_51.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_46.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_306.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_125.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_329.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_301.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_273.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_13.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_318.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_328.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_7.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_44.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_243.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_389.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_115.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_188.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_165.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_126.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_201.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_272.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_281.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_209.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_326.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_178.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_269.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_385.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_173.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_371.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_112.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_78.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_271.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_394.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_203.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_15.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_261.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_225.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_397.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_333.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_270.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_89.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_341.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_82.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_116.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_249.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_109.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_379.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_160.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_220.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_26.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_134.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_287.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_266.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_292.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_362.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_66.jpg (deflated 12%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_236.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_215.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_384.jpg (deflated 9%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_28.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_161.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_354.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_314.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_191.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_250.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_72.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_298.jpg (deflated 10%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_214.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_135.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_355.jpg (deflated 9%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_294.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_179.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_366.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_344.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_45.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_312.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_63.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_399.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_327.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_132.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_380.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_288.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_92.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_392.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_235.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_111.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_374.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_199.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_110.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_184.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_296.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_145.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_22.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_84.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_331.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_364.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_74.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_176.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_148.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_139.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_207.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_210.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_177.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_90.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_373.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_19.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_251.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_56.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_103.jpg (deflated 9%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_387.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_260.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_153.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_372.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_390.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_349.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_154.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_185.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_117.jpg (deflated 12%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_102.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_351.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_98.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_381.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_113.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_40.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_149.jpg (deflated 13%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_297.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_59.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_27.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_170.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_255.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_194.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_324.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_131.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_151.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_167.jpg (deflated 10%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_378.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_285.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_105.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_337.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_5.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_156.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_393.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_221.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_123.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_237.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_311.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_136.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_322.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_377.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_99.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_244.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_8.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_174.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_232.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_346.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_6.jpg (deflated 9%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_2.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_114.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_187.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_338.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_85.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_16.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_38.jpg (deflated 13%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_166.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_39.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_130.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_30.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_283.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_388.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_17.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_396.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_307.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_152.jpg (deflated 12%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_317.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_310.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_3.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_181.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_157.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_228.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_325.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_290.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_4.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_94.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_339.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_222.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_71.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_10.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_293.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_245.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_391.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_345.jpg (deflated 10%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_300.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_358.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_240.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_256.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_305.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_365.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_282.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_279.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_67.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_376.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_267.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_303.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_118.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_246.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_226.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_289.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_80.jpg (deflated 9%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_395.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_69.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_262.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_195.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_208.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_36.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_95.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_206.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_284.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_35.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_202.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_342.jpg (deflated 11%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_334.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_23.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_138.jpg (deflated 1%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_62.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_100.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_37.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_335.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_198.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_106.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_9.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_159.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_183.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_304.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_25.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_189.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_308.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_42.jpg (deflated 8%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_141.jpg (deflated 7%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_353.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_192.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_400.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_1.jpg (deflated 4%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_171.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_241.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_219.jpg (deflated 9%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_190.jpg (deflated 6%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_53.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_108.jpg (deflated 5%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_91.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_264.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_127.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_253.jpg (deflated 2%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no_313.jpg (deflated 3%)
# updating: wrong_predictions/notumor_pred_pituitary/Te-no